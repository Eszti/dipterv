# %%
# Import
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import os
from gensim.models import KeyedVectors

# %%
eng_emb = '/mnt/permanent/Language/Multi/FB/wiki.en/wiki.en.vec'
ita_emb = '/mnt/permanent/Language/Multi/FB/wiki.it/wiki.it.vec'

wp_folder = '/mnt/permanent/home/eszti/dipterv/panlex/data/smith/original/train'

train_fn = 'train_eng_ita.tsv'
valid_fn = 'valid_eng_ita.tsv'

langs = ['eng', 'ita']
idx1 = 0
idx2 = 1
eng = 'eng'
ita = 'ita'

limit = 350000
tr_rat = 9 # tr_rat*10 % will be train data

# %%
def read_emb(emb_fn, limit):
    model = KeyedVectors.load_word2vec_format(emb_fn, binary=False, limit=limit)
    model.syn0 /= np.sqrt((model.syn0 ** 2).sum(1))[:, None]
    return model

# %%
def read_word_pairs_tsv(fn, id1, id2, header=True):
    with open(fn) as f:
        lines = f.readlines()
        data = [(line.split()[id1], line.split()[id2]) for i, line in enumerate(lines) if i > 0 or header == False]
    return data

def get_word_pairs_dict(langs, wp_folder, idx1, idx2):
    word_pairs_dict = dict()
    done = set()
    for lang1 in langs:
        for lang2 in langs:
            lang_pair = tuple(sorted([lang1, lang2]))
            if lang1 == lang2 or lang_pair in done:
                continue
            done.add(lang_pair)
            l1 = lang_pair[0]
            l2 = lang_pair[1]
            fn = os.path.join(wp_folder, '{0}_{1}.tsv'.format(l1, l2))
            print('Reading word pair file: {0}'.format(fn))
            data = read_word_pairs_tsv(fn, idx1, idx2, False)
            word_pairs_dict[lang_pair] = data
            print('Number of word pairs found: {0}'.format(len(data)))
    return word_pairs_dict

# %%
def get_not_found_list(vocab, embedding):
    nf_list = []
    for i, w in enumerate(vocab):
        # Check if there's an embedding to the word
        if w not in embedding:
            nf_list.append(w)
    return nf_list

def wp_list_2_dict(wp_l):
    l12 = dict()
    l21 = dict()
    for (w1, w2) in wp_l:
        if w1 not in l12:
            l12[w1] = [w2]
        else:
            l12[w1].append(w2)
        if w2 not in l21:
            l21[w2] = [w1]
        else:
            l21[w2].append(w1)
    return l12, l21

def get_two_lang_dictionaries(embeddings, word_pairs_dict):
        dictionaries = dict()
        updated_word_pairs = dict()
        for ((l1, l2), wp_l) in word_pairs_dict.items():
            print('Processing {0}-{1}...'.format(l1, l2))
            # Find words without embeddings
            [l1_vocab, l2_vocab] = zip( *wp_l)
            l1_vocab = list(set(l1_vocab))
            l2_vocab = list(set(l2_vocab))
            print('Words in {0}: {1}'.format(l1, len(l1_vocab)))
            print('Words in {0}: {1}'.format(l2, len(l2_vocab)))
            nf_l1 = get_not_found_list(vocab=l1_vocab, embedding=embeddings[l1])
            print('Words not found in embedding {0}: {1}'.format(l1, len(nf_l1)))
            print(nf_l1)
            nf_l2 = get_not_found_list(vocab=l2_vocab, embedding=embeddings[l2])
            print('Words not found in embedding {0}: {1}'.format(l2, len(nf_l2)))
            print(nf_l2)
            # Update word list
            print('Updating word pair list {0}-{1}'.format(l1, l2))
            updated_wp_l = [(w1, w2) for (w1, w2) in wp_l if w1 not in nf_l1 and w2 not in nf_l2]
            print('Word pairs list legth: {0} ->  {1} '.format(len(wp_l), len(updated_wp_l)))
            updated_word_pairs[(l1, l2)] = updated_wp_l
            # Create dictioary
            print('Creating dictionary for: {0}-{1}'.format(l1, l2))
            l12, l21 = wp_list_2_dict(updated_wp_l)
            dictionaries[(l1, l2)] = l12
            dictionaries[(l2, l1)] = l21
            print('# word in: {0}-{1}:\t{2}'.format(l1.upper(), l2, len(l12)))
            print('# word in: {0}-{1}:\t{2}'.format(l2.upper(), l1, len(l21)))
        return dictionaries, updated_word_pairs

# %%
m_en = read_emb(eng_emb, limit)
m_it = read_emb(ita_emb, limit)

# %%
word_pairs_dict = get_word_pairs_dict(langs, wp_folder, idx1, idx2)
# Out:
# Reading word pair file: /mnt/permanent/home/eszti/dipterv/panlex/data/smith/original/train/eng_ita.tsv
# Number of word pairs found: 5000

# %%
embeddings = dict()
embeddings[eng] = m_en
embeddings[ita] = m_it

dictionaries, updated_word_pairs = get_two_lang_dictionaries(embeddings, word_pairs_dict)
# Out:
# Processing eng-ita...
# Words in eng: 3442
# Words in ita: 4549
# Words not found in embedding eng: 0
# []
# Words not found in embedding ita: 1
# ['prelaurea']
# Updating word pair list eng-ita
# Word pairs list legth: 5000 ->  4999
# Creating dictionary for: eng-ita
# # word in: ENG-ita:	3442
# # word in: ITA-eng:	4548

# %%
dictionaries[(eng, ita)]
# Out:
# {'parties': ['parti', 'partiti'],
#  'exposed': ['esposte', 'esposti'],
#  'trying': ['cercando'],
#  'drinks': ['bevande'],
#  'joined': ['aderito'],
#  'fail': ['fail'],
#  'brother': ['fratello'],
#  'component': ['componente'],
#  'understanding': ['comprensione'],
#  'study': ['studio'],
#  'dramatic': ['drammatica', 'drammatiche', 'drammatici', 'drammatico'],
#  'ships': ['navi'],
#  'committee': ['comitato', 'commissione'],
#  'classical': ['classica', 'classico'],
#  'permanent': ['permanente', 'permanenti'],
#  'imperial': ['imperiale', 'imperiali'],
#  'stones': ['pietre'],
#  'rocks': ['rocce', 'scogli'],
#  'destroyed': ['distrutte', 'distrutti', 'distrutto'],
#  'chicago': ['chicago'],
#  'honest': ['onesta', 'onesti', 'onesto'],
#  'fans': ['tifosi'],
#  'investors': ['investitori'],
#  'aware': ['consapevole', 'consapevoli'],
#  'use': ['uso', 'utilizzo'],
#  'peak': ['picco'],
#  'contacts': ['contatti'],
#  'limit': ['limitare', 'limite'],
#  'creating': ['creare'],
#  'album': ['album'],
#  'worst': ['peggio', 'peggiore', 'peggiori'],
#  'craig': ['craig'],
#  'require': ['richiedono'],
#  'mouse': ['topo', 'topolino'],
#  'side': ['side'],
#  'church': ['chiesa'],
#  'cover': ['coprire'],
#  'austria': ['austria'],
#  'worship': ['culto'],
#  'lack': ['mancanza'],
#  'led': ['led', 'portato'],
#  'via': ['via'],
#  'platform': ['piattaforma'],
#  'neil': ['neil'],
#  'disease': ['malattia', 'malattie'],
#  'boston': ['boston'],
#  'sample': ['campione'],
#  'memory': ['memoria'],
#  'briefly': ['brevemente'],
#  'leads': ['porta'],
#  'feeling': ['sensazione'],
#  'sugar': ['zucchero'],
#  'forth': ['forth'],
#  'menu': ['menu', 'menù'],
#  'company': ['azienda', 'impresa'],
#  'guests': ['ospiti'],
#  'rear': ['posteriore'],
#  'reference': ['riferimento'],
#  'cycling': ['ciclismo'],
#  'investment': ['investimenti', 'investimento'],
#  'succeeded': ['riusciti', 'riuscito'],
#  'civil': ['civile', 'civili'],
#  'bags': ['bagagli'],
#  'goal': ['obiettivo'],
#  'afford': ['permetterci', 'permettersi'],
#  'medicine': ['medicina'],
#  'forgotten': ['dimenticati', 'dimenticato'],
#  'hall': ['hall'],
#  'families': ['famiglie'],
#  'linear': ['lineare', 'lineari'],
#  'emergency': ['emergenza'],
#  'basketball': ['pallacanestro'],
#  'duke': ['duca'],
#  'accuracy': ['accuratezza'],
#  'photographs': ['foto', 'fotografie'],
#  'spanish': ['spagnola', 'spagnoli', 'spagnolo'],
#  'otherwise': ['altrimenti'],
#  'trips': ['trips'],
#  'lands': ['terre'],
#  'announcement': ['annuncio'],
#  'metal': ['metallo'],
#  'items': ['voci'],
#  'studying': ['studiando'],
#  'minister': ['ministro'],
#  'exclusive': ['esclusiva', 'esclusive', 'esclusivo'],
#  'acid': ['acide', 'acido'],
#  'afghanistan': ['afghanistan'],
#  'iii': ['iii'],
#  'answer': ['rispondere', 'risposta'],
#  'discovered': ['scoperto'],
#  'premium': ['premio'],
#  'towns': ['città'],
#  'contributed': ['contribuito'],
#  'discount': ['sconto'],
#  'rating': ['rating'],
#  'where': ['dove'],
#  'exeter': ['exeter'],
#  'risk': ['rischio'],
#  'emphasis': ['accento', 'enfasi'],
#  'birds': ['uccelli'],
#  'obtain': ['ottenere'],
#  'capture': ['cattura'],
#  'prevent': ['evitare', 'impedire', 'prevenire'],
#  'temple': ['tempio'],
#  'resolution': ['risoluzione'],
#  'bear': ['bear'],
#  'advantages': ['vantaggi'],
#  'countryside': ['campagne'],
#  'illegal': ['clandestina', 'illegale', 'illegali'],
#  'windows': ['finestre', 'windows'],
#  'evans': ['evans'],
#  'norman': ['norman'],
#  'recruitment': ['assunzione', 'reclutamento'],
#  'muslims': ['musulmani'],
#  'dedicated': ['dedicata', 'dedicato'],
#  'among': ['tra'],
#  'stages': ['fasi'],
#  'theology': ['facoltà', 'teologia'],
#  'presence': ['presenza'],
#  'report': ['relazione'],
#  'introduced': ['introdotto'],
#  'census': ['censimento'],
#  'signed': ['firmato'],
#  'care': ['assistenza'],
#  'dying': ['morire'],
#  'motor': ['automobilistica', 'motore'],
#  'regulations': ['regolamenti'],
#  'purpose': ['scopo'],
#  'edition': ['edizione'],
#  'mixture': ['miscela'],
#  'bob': ['bob'],
#  'importance': ['importanza'],
#  'part': ['parte'],
#  'dreams': ['sogni'],
#  'managers': ['dirigenti', 'gestori'],
#  'service': ['servizio'],
#  'classification': ['classificazione'],
#  'establish': ['istituire', 'stabilire'],
#  'produces': ['produce'],
#  'france': ['francia'],
#  'headed': ['guidata'],
#  'armed': ['armate', 'armati', 'armato'],
#  'case': ['caso'],
#  'seed': ['seed', 'sementi'],
#  'broad': ['ampia', 'ampio'],
#  'flows': ['flussi'],
#  'execution': ['esecuzione'],
#  'worked': ['lavorato'],
#  'temporary': ['temporanea', 'temporanei', 'temporaneo'],
#  'zone': ['zona'],
#  'passion': ['passione'],
#  'dental': ['dentale'],
#  'structures': ['strutture'],
#  'qualified': ['qualificata', 'qualificati'],
#  'criticism': ['critica', 'critiche'],
#  'inspired': ['ispirato'],
#  'planning': ['pianificazione'],
#  'cycle': ['ciclo'],
#  'error': ['errore'],
#  'block': ['bloccare', 'blocco', 'block'],
#  'property': ['proprietà'],
#  'waves': ['ondate'],
#  'joseph': ['joseph'],
#  'duty': ['dovere'],
#  'replace': ['sostituire'],
#  'loop': ['loop'],
#  'conservation': ['conservazione'],
#  'fifth': ['quinta', 'quinto'],
#  'interface': ['interfaccia'],
#  'lose': ['perdere'],
#  'chairman': ['presidente'],
#  'licence': ['licenza', 'patente'],
#  'file': ['fascicolo'],
#  'yesterday': ['ieri'],
#  'ability': ['capacità'],
#  'pennsylvania': ['pennsylvania'],
#  'solo': ['assolo'],
#  'emotional': ['emotiva', 'emotivo'],
#  'maintaining': ['mantenimento'],
#  'musicians': ['musicisti'],
#  'stewart': ['stewart'],
#  'child': ['bambino', 'fanciullo', 'infantile'],
#  'accused': ['accusati', 'accusato'],
#  'call': ['appello'],
#  'reveal': ['rivelano', 'rivelare'],
#  'feelings': ['sentimenti'],
#  'roman': ['roman', 'romana', 'romano'],
#  'baby': ['baby'],
#  'standard': ['standard'],
#  'solution': ['soluzione'],
#  'commission': ['commissione'],
#  'printer': ['stampante', 'stampanti', 'tipografo'],
#  'then': ['allora', 'poi'],
#  'sure': ['sicuro', 'sure'],
#  'safe': ['safe', 'sicura', 'sicuri', 'sicuro'],
#  'growth': ['crescita'],
#  'supported': ['sostenuto'],
#  'him': ['lui'],
#  'soft': ['morbido'],
#  'orders': ['ordini'],
#  'everywhere': ['ovunque'],
#  'threat': ['minaccia'],
#  'high': ['alto', 'elevati', 'elevato'],
#  'her': ['sua'],
#  'immediately': ['immediatamente', 'subito'],
#  'finally': ['finalmente', 'infine'],
#  'priest': ['prete', 'sacerdote'],
#  'sensitive': ['delicata', 'delicato', 'sensibile', 'sensibili'],
#  'computers': ['computer'],
#  'bills': ['bollette'],
#  'agreement': ['accordo'],
#  'profile': ['profilo'],
#  'link': ['collegamento', 'legame'],
#  'culture': ['cultura'],
#  'subjects': ['argomenti'],
#  'instruments': ['strumenti'],
#  'fought': ['combattuto', 'lottato'],
#  'acting': ['agendo'],
#  'found': ['trovato'],
#  'sri': ['lanka'],
#  'ski': ['sci'],
#  'liberal': ['liberale', 'liberali'],
#  'moment': ['momento'],
#  'whenever': ['ogniqualvolta'],
#  'passengers': ['passeggeri'],
#  'vessels': ['imbarcazioni', 'navi', 'pescherecci'],
#  'estimated': ['stimato'],
#  'die': ['die', 'morire', 'muoiono'],
#  'progress': ['progress', 'progressi', 'progresso'],
#  'multiple': ['molteplici'],
#  'june': ['giugno'],
#  'directors': ['direttori'],
#  'anthony': ['anthony'],
#  'kevin': ['kevin'],
#  'diseases': ['malattie'],
#  'formal': ['formale', 'formali'],
#  'son': ['figlio', 'son'],
#  'group': ['gruppo'],
#  'francisco': ['francisco'],
#  'involved': ['coinvolti'],
#  'width': ['larghezza'],
#  'depth': ['profondità'],
#  'equipment': ['apparecchiature', 'attrezzature'],
#  'consideration': ['considerazione'],
#  'abandoned': ['abbandonati', 'abbandonato'],
#  'training': ['formazione'],
#  'del': ['del'],
#  'agricultural': ['agricola', 'agricoli', 'agricolo'],
#  'neck': ['collo'],
#  'equality': ['parità', 'uguaglianza'],
#  'recommendations': ['raccomandazioni'],
#  'sections': ['sezioni'],
#  'presentation': ['presentazione'],
#  'islands': ['isole'],
#  'languages': ['lingue'],
#  'twelve': ['dodici'],
#  'mathematical': ['matematica', 'matematiche', 'matematici', 'matematico'],
#  'wild': ['selvatiche', 'selvatici'],
#  'sports': ['sportive', 'sportivi'],
#  'matters': ['questioni'],
#  'completion': ['completamento'],
#  'ticket': ['biglietti', 'biglietto'],
#  'changes': ['cambiamenti', 'modifiche'],
#  'episodes': ['episodi'],
#  'release': ['liberazione', 'rilascio'],
#  'evil': ['male'],
#  'staff': ['personale'],
#  'exploration': ['esplorazione', 'prospezione'],
#  'apparent': ['apparente'],
#  'glass': ['bicchiere', 'vetro'],
#  'consumption': ['consumo'],
#  'operational': ['operativa', 'operative', 'operativi', 'operativo'],
#  'landing': ['atterraggio'],
#  'summary': ['sintesi'],
#  'grant': ['concedere', 'grant'],
#  'minute': ['minuto'],
#  'assets': ['beni'],
#  'habitat': ['habitat'],
#  'false': ['falsa', 'false', 'falsi', 'falso'],
#  'honour': ['onore'],
#  'privacy': ['privacy'],
#  'their': ['loro'],
#  'tom': ['tom'],
#  'thanks': ['grazie', 'ringraziamenti'],
#  'positive': ['positiva', 'positivi', 'positivo'],
#  'storm': ['tempesta'],
#  'essex': ['essex'],
#  'sound': ['sound'],
#  'imposed': ['imposte', 'imposti', 'imposto'],
#  'rail': ['ferroviari', 'ferroviario', 'rail'],
#  'fantastic': ['fantastico'],
#  'shoes': ['calzature', 'scarpe'],
#  'prince': ['prince', 'principe'],
#  'goods': ['beni', 'merci'],
#  'helps': ['aiuta'],
#  'electronic': ['elettronica', 'elettroniche', 'elettronici', 'elettronico'],
#  'specified': ['specificato'],
#  'agents': ['agenti'],
#  'improve': ['migliorare'],
#  'press': ['stampa'],
#  'recorded': ['registrati', 'registrato'],
#  'assessment': ['valutazione'],
#  'durham': ['durham'],
#  'nothing': ['nulla'],
#  'machines': ['macchine'],
#  'convention': ['convenzione'],
#  'forever': ['forever'],
#  'wireless': ['wireless'],
#  'crimes': ['crimini', 'reati'],
#  'lewis': ['lewis'],
#  'vietnam': ['vietnam'],
#  'employee': ['dipendente'],
#  'repeat': ['ripetere'],
#  'transactions': ['operazioni', 'transazioni'],
#  'air': ['aerei', 'aereo', 'air', 'aria'],
#  'fleet': ['flotta'],
#  'time': ['momento', 'tempo', 'volta'],
#  'spring': ['primavera'],
#  'ocean': ['oceano'],
#  'advise': ['consigliare'],
#  'decision': ['decisione'],
#  'gifts': ['doni', 'regali'],
#  'meaning': ['significato'],
#  'conflict': ['conflitti', 'conflitto'],
#  'offer': ['offerta', 'offrire'],
#  'ben': ['ben'],
#  'consultant': ['consulente'],
#  'concept': ['concetto'],
#  'town': ['città'],
#  'attractive': ['allettante', 'attraente'],
#  'oak': ['quercia', 'rovere'],
#  'now': ['adesso', 'now', 'ora'],
#  'alliance': ['alleanza'],
#  'murray': ['murray'],
#  'greater': ['greater', 'maggiore'],
#  'doors': ['porte'],
#  'seminar': ['seminario'],
#  'functional': ['funzionale', 'funzionali'],
#  'except': ['tranne'],
#  'encouraged': ['incoraggiati', 'incoraggiato'],
#  'produced': ['prodotto'],
#  'white': ['bianchi', 'bianco'],
#  'hot': ['calda', 'caldo', 'fritta'],
#  'bbc': ['bbc'],
#  'that': ['che'],
#  'brazil': ['brasile'],
#  'excellence': ['eccellenza'],
#  'rolling': ['rolling'],
#  'patrick': ['patrick'],
#  'identify': ['identificare', 'individuare'],
#  'action': ['azione'],
#  'represents': ['rappresenta'],
#  'graphics': ['grafica', 'grafico'],
#  'borders': ['confini', 'frontiere'],
#  'note': ['nota'],
#  'weak': ['debole', 'deboli'],
#  'lincoln': ['lincoln'],
#  'awarded': ['assegnato'],
#  'attract': ['attrarre'],
#  'respond': ['rispondere'],
#  'times': ['tempi', 'times', 'volte'],
#  'restaurants': ['ristoranti'],
#  'circle': ['cerchia', 'cerchio', 'circolo', 'polare'],
#  'coat': ['giacca'],
#  'publisher': ['editore'],
#  'tax': ['fiscale', 'fiscali', 'tassa'],
#  'players': ['attori', 'giocatori'],
#  'hamilton': ['hamilton'],
#  'bath': ['bagno', 'sporca'],
#  'cathedral': ['cattedrale'],
#  'inclusion': ['inclusione', 'inserimento'],
#  'towards': ['verso'],
#  'chair': ['presiedere'],
#  'exercise': ['esercitare', 'esercizio'],
#  'treated': ['trattati'],
#  'india': ['india'],
#  'assist': ['assistere'],
#  'constant': ['costante'],
#  'acquired': ['acquisita', 'acquisiti', 'acquisito'],
#  'each': ['ciascuno', 'ogni'],
#  'leaving': ['lasciando'],
#  'desired': ['desiderato'],
#  'poetry': ['poesia'],
#  'engineer': ['ingegnere'],
#  'main': ['meno', 'principale', 'principali'],
#  'nuclear': ['nucleare', 'nucleari'],
#  'healthcare': ['sanitari'],
#  'higher': ['superiore'],
#  'organized': ['organizzata'],
#  'mark': ['marchio', 'marco', 'mark'],
#  'mayor': ['mayor', 'sindaco'],
#  'managed': ['riusciti'],
#  'rooms': ['sale', 'stanze'],
#  'holidays': ['vacanze'],
#  'discuss': ['discutere'],
#  'sheep': ['ovini', 'pecore'],
#  'products': ['prodotti'],
#  'seven': ['sette'],
#  'for': ['per'],
#  'risks': ['rischi'],
#  'protest': ['protesta', 'protestare'],
#  'laws': ['leggi'],
#  'type': ['tipo'],
#  'world': ['mondiale', 'mondo'],
#  'destroy': ['distruggere'],
#  'ball': ['palla'],
#  'possibility': ['possibilità'],
#  'capacity': ['capacità'],
#  'marine': ['marine', 'marini', 'marino'],
#  'cent': ['cento'],
#  'will': ['intende', 'può'],
#  'acquisition': ['acquisizione'],
#  'integration': ['integrazione'],
#  'blog': ['blog'],
#  'personally': ['personalmente'],
#  'ownership': ['proprietà'],
#  'faith': ['fede', 'feith'],
#  'collection': ['raccolta'],
#  'variety': ['varietà'],
#  'daniel': ['daniel'],
#  'leadership': ['guida', 'leadership'],
#  'five': ['cinque'],
#  'poker': ['poker'],
#  'weather': ['meteorologiche'],
#  'doubt': ['dubbio'],
#  'directly': ['direttamente'],
#  'widespread': ['diffusa'],
#  'china': ['cina', 'cristalli', 'porcellane'],
#  'exposure': ['esposizione'],
#  'contact': ['contatti', 'contatto'],
#  'canada': ['canada'],
#  'competition': ['concorrenza'],
#  'alexander': ['alexander'],
#  'ethics': ['etica', 'etico'],
#  'beach': ['beach', 'spiaggia'],
#  'breast': ['materno'],
#  'apple': ['apple', 'mela', 'mele'],
#  'kennedy': ['kennedy'],
#  'mission': ['missione'],
#  'boat': ['barca', 'imbarcazione'],
#  'winter': ['invernali', 'inverno'],
#  'scientific': ['scientifica', 'scientifiche', 'scientifici', 'scientifico'],
#  'administrative': ['amministrativa',
#   'amministrative',
#   'amministrativi',
#   'amministrativo'],
#  'sussex': ['sussex'],
#  'intermediate': ['intermedi', 'intermedia', 'intermedie'],
#  'collections': ['collezioni'],
#  'types': ['tipi'],
#  'adam': ['adam'],
#  'techniques': ['tecniche'],
#  'admitted': ['ammessi', 'ammesso'],
#  'guy': ['guy'],
#  'compliance': ['conformità'],
#  'christianity': ['cristianesimo', 'cristianità'],
#  'competitive': ['competitiva', 'competitivi', 'competitivo'],
#  'specifically': ['specificamente'],
#  'cause': ['causa'],
#  'perfectly': ['perfettamente'],
#  'fed': ['alimentati', 'fed'],
#  'wish': ['desiderio'],
#  'field': ['campo', 'piana', 'polje'],
#  'models': ['modelli'],
#  'acres': ['acri'],
#  'week': ['settimana'],
#  'voted': ['votato'],
#  'oral': ['orale', 'orali'],
#  'expand': ['espandere'],
#  'stuart': ['stuart'],
#  'rome': ['roma'],
#  'presidential': ['presidenziale', 'presidenziali'],
#  'syndrome': ['sindrome'],
#  'recovered': ['recuperati', 'recuperato'],
#  'front': ['front', 'fronte'],
#  'began': ['iniziato'],
#  'signs': ['segnali', 'segni'],
#  'bank': ['banca', 'bancari'],
#  'jews': ['ebrei'],
#  'ensuring': ['garantire'],
#  'cream': ['crema', 'panna'],
#  'growing': ['crescente'],
#  'moscow': ['mosca'],
#  'coaches': ['pullman'],
#  'director': ['direttore'],
#  'target': ['target'],
#  'richard': ['richard'],
#  'technical': ['tecnica', 'tecniche', 'tecnici', 'tecnico'],
#  'spectacular': ['spettacolare', 'spettacolari'],
#  'absolutely': ['assolutamente'],
#  'reputation': ['reputazione'],
#  'gap': ['divario'],
#  'wright': ['wright'],
#  'currently': ['attualmente'],
#  'establishment': ['creazione', 'istituzione'],
#  'berlin': ['berlino'],
#  'level': ['livello'],
#  'brighton': ['brighton'],
#  'locally': ['localmente'],
#  'according': ['secondo'],
#  'met': ['incontrato'],
#  'walk': ['camminare'],
#  'weapon': ['arma'],
#  'opinion': ['opinione', 'parere'],
#  'dimensions': ['dimensioni'],
#  'atlantic': ['atlantica', 'atlantico'],
#  'security': ['sicurezza'],
#  'agency': ['agenzia'],
#  'pressure': ['pressione', 'pressioni'],
#  'von': ['von'],
#  'scholars': ['studiosi'],
#  'opposite': ['opposto'],
#  'jan': ['jan'],
#  'quickly': ['rapidamente'],
#  'revolutionary': ['rivoluzionari',
#   'rivoluzionaria',
#   'rivoluzionarie',
#   'rivoluzionario'],
#  'assume': ['assumersi'],
#  'office': ['carica', 'ufficio'],
#  'actions': ['azioni'],
#  'membership': ['adesione'],
#  'big': ['big', 'grande', 'grandi'],
#  'trophy': ['trofei'],
#  'phone': ['telefonia', 'telefono'],
#  'traditionally': ['tradizionalmente'],
#  'meals': ['pasti'],
#  'session': ['sessione'],
#  'peter': ['peter'],
#  'manufacture': ['fabbricazione'],
#  'commissioner': ['commissario'],
#  'sir': ['sir'],
#  'certainly': ['certamente', 'sicuramente'],
#  'aims': ['mira'],
#  'sleep': ['dormire', 'sonno'],
#  'confirmed': ['confermato'],
#  'control': ['controllo'],
#  'flag': ['bandiera'],
#  'pension': ['pensione', 'pensionistici'],
#  'temperature': ['temperatura'],
#  'common': ['comune', 'comuni'],
#  'two': ['due'],
#  'commonwealth': ['commonwealth'],
#  'save': ['risparmiare', 'salvare', 'save'],
#  'lost': ['perso'],
#  'experience': ['esperienza'],
#  'egypt': ['egitto'],
#  'qualification': ['qualifica', 'qualificazione'],
#  'rent': ['affitto'],
#  'considerable': ['notevole', 'notevoli'],
#  'thursday': ['giovedì'],
#  'interviews': ['interviste'],
#  'formula': ['formula'],
#  'biography': ['biografia'],
#  'similarly': ['analogamente'],
#  'increased': ['maggiore'],
#  'illness': ['malattia'],
#  'rights': ['diritti'],
#  'cameras': ['telecamere'],
#  'operation': ['funzionamento', 'operazione'],
#  'swedish': ['svedese', 'svedesi'],
#  'dual': ['doppia', 'duplice'],
#  'taxes': ['imposte', 'tasse'],
#  'periods': ['periodi'],
#  'project': ['progetto'],
#  'negotiations': ['negoziati'],
#  'strong': ['forte', 'forti'],
#  'replaced': ['sostituita', 'sostituiti', 'sostituito'],
#  'defeated': ['sconfitto'],
#  'theatre': ['teatro'],
#  'tracks': ['binari'],
#  'category': ['categoria', 'rubrica'],
#  'aircraft': ['aerei', 'aeromobili', 'aircraft'],
#  'william': ['william'],
#  'devon': ['devon'],
#  'forest': ['boschivi', 'forest', 'forestali'],
#  'georgia': ['georgia'],
#  'fantasy': ['fantasia'],
#  'plastic': ['plastica'],
#  'heart': ['centro', 'cuore'],
#  'especially': ['particolare', 'soprattutto'],
#  'shipping': ['navigazione'],
#  'lower': ['bassa', 'inferiori'],
#  'allied': ['alleate'],
#  'jason': ['jason'],
#  'regard': ['proposito'],
#  'tried': ['cercato', 'tentato'],
#  'sand': ['sabbia'],
#  'corresponding': ['corrispondente', 'corrispondenti'],
#  'walked': ['camminato'],
#  'graphic': ['grafici'],
#  'indicated': ['indicato'],
#  'refugees': ['profughi', 'rifugiati'],
#  'ordered': ['ordinato'],
#  'spaces': ['spazi'],
#  'noticed': ['notato'],
#  'information': ['informazione', 'informazioni'],
#  'winning': ['vincere'],
#  'seek': ['cercare'],
#  'regeneration': ['rigenerazione'],
#  'memorial': ['memorial'],
#  'brilliant': ['brillante'],
#  'river': ['fiume', 'fluviale', 'fluviali'],
#  'distance': ['distanza'],
#  'rob': ['rob'],
#  'stadium': ['stadium'],
#  'effort': ['sforzo'],
#  'owners': ['proprietari'],
#  'forward': ['avanti'],
#  'storage': ['stoccaggio'],
#  'negative': ['negativa', 'negative', 'negativi', 'negativo'],
#  'developments': ['sviluppi'],
#  'apply': ['applicare'],
#  'export': ['esportare', 'esportazione'],
#  'detail': ['dettagli', 'dettaglio'],
#  'counties': ['contee'],
#  'known': ['nota', 'noto'],
#  'executed': ['giustiziati', 'giustiziato'],
#  'forum': ['forum'],
#  'seconds': ['secondi'],
#  'steps': ['passi'],
#  'enjoy': ['godere'],
#  'cases': ['casi'],
#  'education': ['istruzione'],
#  'focus': ['concentrarsi', 'focus'],
#  'around': ['circa'],
#  'asylum': ['asilo'],
#  'wilson': ['wilson'],
#  'tony': ['tony'],
#  'yet': ['ancora'],
#  'iran': ['iran'],
#  'sign': ['firmare', 'segnale', 'segno'],
#  'islamic': ['islamica', 'islamici', 'islamico'],
#  'public': ['pubblica', 'pubblici', 'pubblico'],
#  'neighbourhood': ['vicinato'],
#  'actress': ['attrice'],
#  'servers': ['server'],
#  'between': ['fra', 'tra'],
#  'edward': ['edward'],
#  'urban': ['urban', 'urbana', 'urbane', 'urbani', 'urbano'],
#  'weapons': ['armi'],
#  'positions': ['posizioni'],
#  'investigations': ['indagini'],
#  'suggestions': ['suggerimenti'],
#  'weeks': ['settimane'],
#  'survival': ['sopravvivenza'],
#  'way': ['modo'],
#  'rules': ['norme', 'regolamento', 'regole'],
#  'attempting': ['tentando'],
#  'wing': ['ala'],
#  'opposition': ['opposizione'],
#  'reverse': ['invertire'],
#  'classic': ['classica', 'classico'],
#  'geography': ['geografia'],
#  'matter': ['questione'],
#  'living': ['vita'],
#  'pilot': ['pilota'],
#  'hampshire': ['hampshire'],
#  'solid': ['solida', 'solide', 'solido'],
#  'challenges': ['sfide'],
#  'wisdom': ['saggezza'],
#  'six': ['sei'],
#  'breaking': ['breaking'],
#  'contemporary': ['contemporanea', 'contemporaneo'],
#  'publicly': ['pubblicamente'],
#  'java': ['giava'],
#  'term': ['semestre', 'termine'],
#  'map': ['map', 'marcia'],
#  'jesus': ['gesù'],
#  'reflects': ['riflette', 'rispecchia'],
#  'blood': ['sangue'],
#  'marketing': ['commercializzazione'],
#  'ask': ['chiedere'],
#  'reaction': ['reazione'],
#  'loan': ['prestito'],
#  'occupational': ['professionali'],
#  'collaboration': ['collaboration', 'collaborazione'],
#  'spending': ['spesa'],
#  'legend': ['leggenda'],
#  'these': ['queste', 'questi', 'tali'],
#  'wales': ['galles'],
#  'enter': ['entrare'],
#  'dvd': ['dvd'],
#  'jean': ['jean'],
#  'say': ['dire'],
#  'consistent': ['coerente', 'coerenti'],
#  'pleasant': ['piacevole'],
#  'fair': ['equa', 'equo', 'fair'],
#  'walker': ['walker'],
#  'postgraduate': ['postlaurea'],
#  'necessary': ['necessari', 'necessaria', 'necessarie', 'necessario'],
#  'plants': ['impianti', 'piante'],
#  'sunday': ['domenica'],
#  'lake': ['lago'],
#  'page': ['pagina'],
#  'archive': ['archivio'],
#  'unions': ['sindacati'],
#  'character': ['carattere'],
#  'center': ['center'],
#  'ict': ['tic'],
#  'feed': ['mangimi'],
#  'limited': ['limitata', 'limitate', 'limitato', 'limited'],
#  'slowly': ['lentamente'],
#  'cope': ['cope'],
#  'medical': ['medica', 'medical', 'mediche', 'medici', 'medico'],
#  'royal': ['royal'],
#  'williams': ['williams'],
#  'belfast': ['belfast'],
#  'buried': ['sepolta', 'sepolto'],
#  'brings': ['porta'],
#  'cricket': ['cricket'],
#  'literally': ['letteralmente'],
#  'melbourne': ['melbourne'],
#  'shares': ['condivide'],
#  'desk': ['scrivania'],
#  'paint': ['vernice'],
#  'logic': ['logica'],
#  'force': ['force', 'forza', 'vigore'],
#  'thomas': ['thomas'],
#  'underground': ['sotterranee'],
#  'monday': ['lunedì'],
#  'christian': ['cristiana', 'cristiane', 'cristiani', 'cristiano'],
#  'cuts': ['tagli'],
#  'path': ['cammino', 'percorso', 'strada'],
#  'circumstances': ['circostanze'],
#  'british': ['britannica', 'britannici', 'britannico'],
#  'nature': ['carattere', 'natura', 'nature'],
#  'structure': ['struttura'],
#  'works': ['funziona', 'opere'],
#  'courses': ['corsi'],
#  'continental': ['continentale', 'continentali'],
#  'kinds': ['tipi'],
#  'wave': ['ondata'],
#  'seeds': ['sementi', 'semi'],
#  'include': ['includere'],
#  'meets': ['soddisfa'],
#  'eight': ['otto'],
#  'scenes': ['quinte', 'scene'],
#  'society': ['società'],
#  'normally': ['normalmente'],
#  'button': ['bottone', 'pulsante', 'tasto'],
#  'mainly': ['principalmente'],
#  'interest': ['interesse'],
#  'been': ['stata', 'stati', 'stato'],
#  'body': ['corpo', 'organismo', 'organo'],
#  'last': ['scorso', 'ultima', 'ultimi', 'ultimo'],
#  'actor': ['attore'],
#  'channels': ['canali'],
#  'wars': ['guerre'],
#  'feature': ['caratteristica'],
#  'clubs': ['club'],
#  'achievement': ['raggiungimento'],
#  'howard': ['howard'],
#  'mrs': ['onorevole'],
#  'tourist': ['turistica', 'turistiche', 'turistici', 'turistico'],
#  'hole': ['buco'],
#  'twenty': ['venti'],
#  'properly': ['adeguatamente', 'correttamente'],
#  'shower': ['doccia'],
#  'liverpool': ['liverpool'],
#  'film': ['cinematografica', 'cinematografico', 'film'],
#  'illinois': ['illinois'],
#  'van': ['van'],
#  'plan': ['piano'],
#  'daughter': ['figlia'],
#  'situations': ['situazioni'],
#  'characteristics': ['caratteristiche'],
#  'prisoners': ['detenuti', 'prigionieri'],
#  'hopes': ['speranze'],
#  'paul': ['paolo', 'paul'],
#  'here': ['qui'],
#  'interactive': ['interattiva', 'interattivi', 'interattivo'],
#  'jimmy': ['jimmy'],
#  'patients': ['pazienti'],
#  'east': ['est'],
#  'write': ['scrivere'],
#  'experiences': ['esperienze'],
#  'hair': ['capelli'],
#  'mature': ['matura', 'maturo'],
#  'distributed': ['distribuita', 'distribuiti', 'distribuito'],
#  'adoption': ['adozione', 'approvazione'],
#  'future': ['futuro'],
#  'gary': ['gary'],
#  'worldwide': ['worldwide'],
#  'governance': ['governance'],
#  'issue': ['problema', 'questione', 'tema'],
#  'content': ['content', 'contenuti', 'contenuto'],
#  'readers': ['lettori'],
#  'want': ['want'],
#  'accompanied': ['accompagnata', 'accompagnato'],
#  'guilty': ['colpevole', 'colpevoli'],
#  'won': ['vinto'],
#  'moon': ['luna', 'moon'],
#  'class': ['classe'],
#  'teachers': ['insegnanti'],
#  'integrated': ['integrata', 'integrati', 'integrato'],
#  'southern': ['meridionale', 'meridionali'],
#  'module': ['modulo'],
#  'always': ['sempre'],
#  'improving': ['miglioramento', 'migliorare'],
#  'australia': ['australia'],
#  'commercial': ['commerciale', 'commerciali'],
#  'production': ['produzione'],
#  'rugby': ['rugby'],
#  'northern': ['nord', 'settentrionale', 'settentrionali'],
#  'made': ['made'],
#  'rock': ['roccia', 'rock'],
#  'transformation': ['trasformazione'],
#  'safety': ['safety', 'sicurezza'],
#  'sitting': ['seduta'],
#  'tonight': ['stasera'],
#  'covers': ['copre'],
#  'controversial': ['controversa', 'controverse', 'controversi', 'controverso'],
#  'understand': ['capire', 'comprendere'],
#  'benefits': ['benefici', 'vantaggi'],
#  'perhaps': ['forse'],
#  'videos': ['video'],
#  'resources': ['risorse'],
#  'october': ['ottobre'],
#  'hear': ['sentire'],
#  'fox': ['fox', 'volpe'],
#  'piece': ['pezzo'],
#  'environmental': ['ambientale', 'ambientali'],
#  'response': ['risposta'],
#  'eastern': ['orientale', 'orientali'],
#  'remain': ['restare', 'rimanere'],
#  'fourth': ['quarta', 'quarto'],
#  'banks': ['banche'],
#  'features': ['caratteristiche'],
#  'glory': ['gloria'],
#  'architecture': ['architettura'],
#  'sisters': ['sorelle'],
#  'domestic': ['interna'],
#  'incident': ['incidente'],
#  'virtually': ['praticamente'],
#  'undertaking': ['impresa'],
#  'thoughts': ['pensieri', 'riflessioni'],
#  'degrees': ['gradi'],
#  'extreme': ['estrema'],
#  'final': ['finale', 'ultima'],
#  'wear': ['indossare'],
#  'homes': ['abitazioni', 'case'],
#  'ground': ['terreno'],
#  'representatives': ['rappresentanti'],
#  'begun': ['iniziato'],
#  'bond': ['bond', 'obbligazionario'],
#  'reasonably': ['ragionevolmente'],
#  'media': ['media'],
#  'earn': ['guadagnano', 'guadagnare'],
#  'books': ['books', 'libri'],
#  'digital': ['digitale', 'digitali'],
#  'tribunal': ['tribunale'],
#  'nicholas': ['nicholas'],
#  'course': ['corso'],
#  'occupied': ['occupata', 'occupati', 'occupato'],
#  'listening': ['ascolto'],
#  'may': ['maggio', 'possono'],
#  'oliver': ['oliver'],
#  'professionals': ['professionisti'],
#  'association': ['associazione'],
#  'buildings': ['edifici'],
#  'intelligent': ['intelligente', 'intelligenti'],
#  'forests': ['foreste'],
#  'russian': ['russa', 'russe', 'russi', 'russo'],
#  'wrong': ['sbagliata', 'sbagliato'],
#  'radio': ['radio'],
#  'take': ['prendere'],
#  'installation': ['installazione'],
#  'closely': ['strettamente'],
#  'christ': ['cristo'],
#  'electrical': ['elettrica', 'elettriche', 'elettrici'],
#  'difficulty': ['difficoltà'],
#  'continues': ['continua'],
#  'consultation': ['consultazione'],
#  'joint': ['comune', 'congiunta', 'mista', 'paritetica'],
#  'identified': ['individuato'],
#  'devices': ['dispositivi'],
#  'district': ['distretto', 'distrettuale', 'district'],
#  'organization': ['organizzazione'],
#  'boys': ['boys', 'ragazzi'],
#  'hardware': ['hardware'],
#  'secretary': ['segretario'],
#  'trials': ['trials'],
#  'afternoon': ['pomeriggio'],
#  'addressed': ['affrontato'],
#  'cap': ['cap', 'pac'],
#  'french': ['francese', 'francesi'],
#  'opening': ['apertura'],
#  'easily': ['facilmente'],
#  'materials': ['materiali'],
#  'original': ['originale', 'originaria'],
#  'chat': ['chat'],
#  'develop': ['sviluppare'],
#  'iraqi': ['irachena', 'iracheni', 'iracheno'],
#  'first': ['prima', 'primo'],
#  'promoting': ['promozione', 'promuovere'],
#  'objective': ['obiettivo'],
#  'soviet': ['sovietica', 'sovietico'],
#  'attitude': ['atteggiamento'],
#  'exchange': ['exchange', 'scambio'],
#  'partner': ['partner'],
#  'occasional': ['occasionale', 'occasionali'],
#  'demonstrated': ['dimostrato'],
#  'campaign': ['campagna', 'campaign'],
#  'screening': ['screening'],
#  'blind': ['cieca', 'cieco'],
#  'lay': ['gettare'],
#  'replied': ['risposto'],
#  'expensive': ['costosa', 'costosi', 'costoso'],
#  'slow': ['lenta', 'lenti', 'lento'],
#  'various': ['diverse', 'diversi', 'vari', 'varie'],
#  'fascinating': ['affascinante'],
#  'walter': ['walter'],
#  'orange': ['arancione', 'orange'],
#  'machine': ['macchina'],
#  'modern': ['moderna', 'moderne', 'moderni', 'moderno'],
#  'major': ['grandi', 'major'],
#  'opens': ['apre'],
#  'audit': ['audit'],
#  'difference': ['differenza'],
#  'knew': ['sapeva', 'sapevano'],
#  'netherlands': ['bassi'],
#  'system': ['sistema'],
#  'signing': ['firma'],
#  'clear': ['chiara', 'chiaro'],
#  'acted': ['agito'],
#  'adult': ['adulta', 'adulte', 'adulti', 'adulto'],
#  'treatment': ['trattamento'],
#  'boxes': ['scatole'],
#  'under': ['sotto'],
#  'retirement': ['pensionabile', 'pensionamento'],
#  'museums': ['musei'],
#  'island': ['insulari', 'isola'],
#  'failed': ['fallito'],
#  'cultures': ['culture'],
#  'king': ['king'],
#  'broadcasting': ['broadcasting',
#   'fiera',
#   'radiodiffusione',
#   'radiotelevisiva'],
#  'hills': ['colline'],
#  'respectively': ['rispettivamente'],
#  'ease': ['facilità'],
#  'existing': ['esistente', 'esistenti'],
#  'philadelphia': ['filadelfia'],
#  'calendar': ['calendario'],
#  'room': ['margine'],
#  'filter': ['filtrare', 'filtro'],
#  'clark': ['clark'],
#  'invasion': ['invasione'],
#  'round': ['ciclo', 'round', 'tornata'],
#  'midlands': ['midlands'],
#  'damage': ['danni', 'danno'],
#  'today': ['oggi'],
#  'since': ['poiché'],
#  'premises': ['premesse'],
#  'test': ['prova', 'test'],
#  'kill': ['morte', 'uccidere', 'uccidono'],
#  'universe': ['universo'],
#  'legislation': ['legislazione'],
#  'hate': ['odio'],
#  'individuals': ['individui'],
#  'newspaper': ['giornale', 'quotidiano'],
#  'league': ['campionato', 'lega'],
#  'join': ['aderire'],
#  'demand': ['domanda'],
#  'protected': ['protetti', 'tutelati'],
#  'search': ['search'],
#  'win': ['vincere', 'win'],
#  'soul': ['anima', 'soul'],
#  'technology': ['tecnologia', 'tecnologie'],
#  'subsequent': ['successiva', 'successive', 'successivi'],
#  'options': ['opzioni'],
#  'europe': ['europa'],
#  'commitment': ['impegno'],
#  'scotland': ['scozia'],
#  'publish': ['pubblicare'],
#  'list': ['elenco', 'lista'],
#  'combined': ['combinato'],
#  'low': ['bassi', 'basso'],
#  'user': ['utente'],
#  'reached': ['raggiunto'],
#  'customs': ['doganale', 'doganali'],
#  'jurisdiction': ['giurisdizione'],
#  'episode': ['episodio'],
#  'catalogue': ['catalogo'],
#  'interests': ['interesse', 'interessi'],
#  'approval': ['approvazione', 'elezione'],
#  'ceremony': ['cerimonia'],
#  'crisis': ['crisi'],
#  'arms': ['armi'],
#  'largely': ['ampiamente'],
#  'conventional': ['convenzionale', 'convenzionali'],
#  'codes': ['codici'],
#  'prepare': ['preparare'],
#  'guarantee': ['garantire', 'garanzia'],
#  'receive': ['ricevere'],
#  'forget': ['dimenticare'],
#  'workshop': ['workshop'],
#  'casino': ['casinò'],
#  'scene': ['scena'],
#  'innovative': ['innovativa', 'innovative', 'innovativi', 'innovativo'],
#  'documents': ['documenti'],
#  'youth': ['giovanile', 'gioventù', 'youth'],
#  'saving': ['risparmio', 'salvare'],
#  'vat': ['iva'],
#  'leader': ['capo', 'leader'],
#  'listed': ['elencati'],
#  'implementation': ['applicazione', 'attuazione'],
#  ...}

# %%
def split(dictionaries):
    i = 0
    tr = []
    val = []
    for (k, vals) in dictionaries[(eng, ita)].items():
        wp_s = []
        for v in vals:
            wp_s.append((k, v))
        if i % 10 < tr_rat:
            tr += wp_s
        else:
            val += wp_s
        i += 1
    return tr, val

# %%
train_wps, valid_wps = split(dictionaries)

# %%
len(train_wps)
len(valid_wps)
# Out:
# 4498
# 501

# %%
train_wps
# Out:
# [('parties', 'parti'),
#  ('parties', 'partiti'),
#  ('exposed', 'esposte'),
#  ('exposed', 'esposti'),
#  ('trying', 'cercando'),
#  ('drinks', 'bevande'),
#  ('joined', 'aderito'),
#  ('fail', 'fail'),
#  ('brother', 'fratello'),
#  ('component', 'componente'),
#  ('understanding', 'comprensione'),
#  ('dramatic', 'drammatica'),
#  ('dramatic', 'drammatiche'),
#  ('dramatic', 'drammatici'),
#  ('dramatic', 'drammatico'),
#  ('ships', 'navi'),
#  ('committee', 'comitato'),
#  ('committee', 'commissione'),
#  ('classical', 'classica'),
#  ('classical', 'classico'),
#  ('permanent', 'permanente'),
#  ('permanent', 'permanenti'),
#  ('imperial', 'imperiale'),
#  ('imperial', 'imperiali'),
#  ('stones', 'pietre'),
#  ('rocks', 'rocce'),
#  ('rocks', 'scogli'),
#  ('destroyed', 'distrutte'),
#  ('destroyed', 'distrutti'),
#  ('destroyed', 'distrutto'),
#  ('honest', 'onesta'),
#  ('honest', 'onesti'),
#  ('honest', 'onesto'),
#  ('fans', 'tifosi'),
#  ('investors', 'investitori'),
#  ('aware', 'consapevole'),
#  ('aware', 'consapevoli'),
#  ('use', 'uso'),
#  ('use', 'utilizzo'),
#  ('peak', 'picco'),
#  ('contacts', 'contatti'),
#  ('limit', 'limitare'),
#  ('limit', 'limite'),
#  ('creating', 'creare'),
#  ('worst', 'peggio'),
#  ('worst', 'peggiore'),
#  ('worst', 'peggiori'),
#  ('craig', 'craig'),
#  ('require', 'richiedono'),
#  ('mouse', 'topo'),
#  ('mouse', 'topolino'),
#  ('side', 'side'),
#  ('church', 'chiesa'),
#  ('cover', 'coprire'),
#  ('austria', 'austria'),
#  ('worship', 'culto'),
#  ('led', 'led'),
#  ('led', 'portato'),
#  ('via', 'via'),
#  ('platform', 'piattaforma'),
#  ('neil', 'neil'),
#  ('disease', 'malattia'),
#  ('disease', 'malattie'),
#  ('boston', 'boston'),
#  ('sample', 'campione'),
#  ('memory', 'memoria'),
#  ('briefly', 'brevemente'),
#  ('feeling', 'sensazione'),
#  ('sugar', 'zucchero'),
#  ('forth', 'forth'),
#  ('menu', 'menu'),
#  ('menu', 'menù'),
#  ('company', 'azienda'),
#  ('company', 'impresa'),
#  ('guests', 'ospiti'),
#  ('rear', 'posteriore'),
#  ('reference', 'riferimento'),
#  ('cycling', 'ciclismo'),
#  ('succeeded', 'riusciti'),
#  ('succeeded', 'riuscito'),
#  ('civil', 'civile'),
#  ('civil', 'civili'),
#  ('bags', 'bagagli'),
#  ('goal', 'obiettivo'),
#  ('afford', 'permetterci'),
#  ('afford', 'permettersi'),
#  ('medicine', 'medicina'),
#  ('forgotten', 'dimenticati'),
#  ('forgotten', 'dimenticato'),
#  ('hall', 'hall'),
#  ('families', 'famiglie'),
#  ('emergency', 'emergenza'),
#  ('basketball', 'pallacanestro'),
#  ('duke', 'duca'),
#  ('accuracy', 'accuratezza'),
#  ('photographs', 'foto'),
#  ('photographs', 'fotografie'),
#  ('spanish', 'spagnola'),
#  ('spanish', 'spagnoli'),
#  ('spanish', 'spagnolo'),
#  ('otherwise', 'altrimenti'),
#  ('trips', 'trips'),
#  ('lands', 'terre'),
#  ('metal', 'metallo'),
#  ('items', 'voci'),
#  ('studying', 'studiando'),
#  ('minister', 'ministro'),
#  ('exclusive', 'esclusiva'),
#  ('exclusive', 'esclusive'),
#  ('exclusive', 'esclusivo'),
#  ('acid', 'acide'),
#  ('acid', 'acido'),
#  ('afghanistan', 'afghanistan'),
#  ('iii', 'iii'),
#  ('answer', 'rispondere'),
#  ('answer', 'risposta'),
#  ('premium', 'premio'),
#  ('towns', 'città'),
#  ('contributed', 'contribuito'),
#  ('discount', 'sconto'),
#  ('rating', 'rating'),
#  ('where', 'dove'),
#  ('exeter', 'exeter'),
#  ('risk', 'rischio'),
#  ('emphasis', 'accento'),
#  ('emphasis', 'enfasi'),
#  ('obtain', 'ottenere'),
#  ('capture', 'cattura'),
#  ('prevent', 'evitare'),
#  ('prevent', 'impedire'),
#  ('prevent', 'prevenire'),
#  ('temple', 'tempio'),
#  ('resolution', 'risoluzione'),
#  ('bear', 'bear'),
#  ('advantages', 'vantaggi'),
#  ('countryside', 'campagne'),
#  ('illegal', 'clandestina'),
#  ('illegal', 'illegale'),
#  ('illegal', 'illegali'),
#  ('evans', 'evans'),
#  ('norman', 'norman'),
#  ('recruitment', 'assunzione'),
#  ('recruitment', 'reclutamento'),
#  ('muslims', 'musulmani'),
#  ('dedicated', 'dedicata'),
#  ('dedicated', 'dedicato'),
#  ('among', 'tra'),
#  ('stages', 'fasi'),
#  ('theology', 'facoltà'),
#  ('theology', 'teologia'),
#  ('presence', 'presenza'),
#  ('introduced', 'introdotto'),
#  ('census', 'censimento'),
#  ('signed', 'firmato'),
#  ('care', 'assistenza'),
#  ('dying', 'morire'),
#  ('motor', 'automobilistica'),
#  ('motor', 'motore'),
#  ('regulations', 'regolamenti'),
#  ('purpose', 'scopo'),
#  ('edition', 'edizione'),
#  ('bob', 'bob'),
#  ('importance', 'importanza'),
#  ('part', 'parte'),
#  ('dreams', 'sogni'),
#  ('managers', 'dirigenti'),
#  ('managers', 'gestori'),
#  ('service', 'servizio'),
#  ('classification', 'classificazione'),
#  ('establish', 'istituire'),
#  ('establish', 'stabilire'),
#  ('produces', 'produce'),
#  ('headed', 'guidata'),
#  ('armed', 'armate'),
#  ('armed', 'armati'),
#  ('armed', 'armato'),
#  ('case', 'caso'),
#  ('seed', 'seed'),
#  ('seed', 'sementi'),
#  ('broad', 'ampia'),
#  ('broad', 'ampio'),
#  ('flows', 'flussi'),
#  ('execution', 'esecuzione'),
#  ('worked', 'lavorato'),
#  ('temporary', 'temporanea'),
#  ('temporary', 'temporanei'),
#  ('temporary', 'temporaneo'),
#  ('passion', 'passione'),
#  ('dental', 'dentale'),
#  ('structures', 'strutture'),
#  ('qualified', 'qualificata'),
#  ('qualified', 'qualificati'),
#  ('criticism', 'critica'),
#  ('criticism', 'critiche'),
#  ('inspired', 'ispirato'),
#  ('planning', 'pianificazione'),
#  ('cycle', 'ciclo'),
#  ('error', 'errore'),
#  ('property', 'proprietà'),
#  ('waves', 'ondate'),
#  ('joseph', 'joseph'),
#  ('duty', 'dovere'),
#  ('replace', 'sostituire'),
#  ('loop', 'loop'),
#  ('conservation', 'conservazione'),
#  ('fifth', 'quinta'),
#  ('fifth', 'quinto'),
#  ('interface', 'interfaccia'),
#  ('chairman', 'presidente'),
#  ('licence', 'licenza'),
#  ('licence', 'patente'),
#  ('file', 'fascicolo'),
#  ('yesterday', 'ieri'),
#  ('ability', 'capacità'),
#  ('pennsylvania', 'pennsylvania'),
#  ('solo', 'assolo'),
#  ('emotional', 'emotiva'),
#  ('emotional', 'emotivo'),
#  ('maintaining', 'mantenimento'),
#  ('stewart', 'stewart'),
#  ('child', 'bambino'),
#  ('child', 'fanciullo'),
#  ('child', 'infantile'),
#  ('accused', 'accusati'),
#  ('accused', 'accusato'),
#  ('call', 'appello'),
#  ('reveal', 'rivelano'),
#  ('reveal', 'rivelare'),
#  ('feelings', 'sentimenti'),
#  ('roman', 'roman'),
#  ('roman', 'romana'),
#  ('roman', 'romano'),
#  ('baby', 'baby'),
#  ('standard', 'standard'),
#  ('commission', 'commissione'),
#  ('printer', 'stampante'),
#  ('printer', 'stampanti'),
#  ('printer', 'tipografo'),
#  ('then', 'allora'),
#  ('then', 'poi'),
#  ('sure', 'sicuro'),
#  ('sure', 'sure'),
#  ('safe', 'safe'),
#  ('safe', 'sicura'),
#  ('safe', 'sicuri'),
#  ('safe', 'sicuro'),
#  ('growth', 'crescita'),
#  ('supported', 'sostenuto'),
#  ('him', 'lui'),
#  ('soft', 'morbido'),
#  ('everywhere', 'ovunque'),
#  ('threat', 'minaccia'),
#  ('high', 'alto'),
#  ('high', 'elevati'),
#  ('high', 'elevato'),
#  ('her', 'sua'),
#  ('immediately', 'immediatamente'),
#  ('immediately', 'subito'),
#  ('finally', 'finalmente'),
#  ('finally', 'infine'),
#  ('priest', 'prete'),
#  ('priest', 'sacerdote'),
#  ('sensitive', 'delicata'),
#  ('sensitive', 'delicato'),
#  ('sensitive', 'sensibile'),
#  ('sensitive', 'sensibili'),
#  ('computers', 'computer'),
#  ('agreement', 'accordo'),
#  ('profile', 'profilo'),
#  ('link', 'collegamento'),
#  ('link', 'legame'),
#  ('culture', 'cultura'),
#  ('subjects', 'argomenti'),
#  ('instruments', 'strumenti'),
#  ('fought', 'combattuto'),
#  ('fought', 'lottato'),
#  ('acting', 'agendo'),
#  ('found', 'trovato'),
#  ('ski', 'sci'),
#  ('liberal', 'liberale'),
#  ('liberal', 'liberali'),
#  ('moment', 'momento'),
#  ('whenever', 'ogniqualvolta'),
#  ('passengers', 'passeggeri'),
#  ('vessels', 'imbarcazioni'),
#  ('vessels', 'navi'),
#  ('vessels', 'pescherecci'),
#  ('estimated', 'stimato'),
#  ('die', 'die'),
#  ('die', 'morire'),
#  ('die', 'muoiono'),
#  ('progress', 'progress'),
#  ('progress', 'progressi'),
#  ('progress', 'progresso'),
#  ('june', 'giugno'),
#  ('directors', 'direttori'),
#  ('anthony', 'anthony'),
#  ('kevin', 'kevin'),
#  ('diseases', 'malattie'),
#  ('formal', 'formale'),
#  ('formal', 'formali'),
#  ('son', 'figlio'),
#  ('son', 'son'),
#  ('group', 'gruppo'),
#  ('francisco', 'francisco'),
#  ('width', 'larghezza'),
#  ('depth', 'profondità'),
#  ('equipment', 'apparecchiature'),
#  ('equipment', 'attrezzature'),
#  ('consideration', 'considerazione'),
#  ('abandoned', 'abbandonati'),
#  ('abandoned', 'abbandonato'),
#  ('training', 'formazione'),
#  ('del', 'del'),
#  ('agricultural', 'agricola'),
#  ('agricultural', 'agricoli'),
#  ('agricultural', 'agricolo'),
#  ('neck', 'collo'),
#  ('recommendations', 'raccomandazioni'),
#  ('sections', 'sezioni'),
#  ('presentation', 'presentazione'),
#  ('islands', 'isole'),
#  ('languages', 'lingue'),
#  ('twelve', 'dodici'),
#  ('mathematical', 'matematica'),
#  ('mathematical', 'matematiche'),
#  ('mathematical', 'matematici'),
#  ('mathematical', 'matematico'),
#  ('wild', 'selvatiche'),
#  ('wild', 'selvatici'),
#  ('sports', 'sportive'),
#  ('sports', 'sportivi'),
#  ('completion', 'completamento'),
#  ('ticket', 'biglietti'),
#  ('ticket', 'biglietto'),
#  ('changes', 'cambiamenti'),
#  ('changes', 'modifiche'),
#  ('episodes', 'episodi'),
#  ('release', 'liberazione'),
#  ('release', 'rilascio'),
#  ('evil', 'male'),
#  ('staff', 'personale'),
#  ('exploration', 'esplorazione'),
#  ('exploration', 'prospezione'),
#  ('apparent', 'apparente'),
#  ('consumption', 'consumo'),
#  ('operational', 'operativa'),
#  ('operational', 'operative'),
#  ('operational', 'operativi'),
#  ('operational', 'operativo'),
#  ('landing', 'atterraggio'),
#  ('summary', 'sintesi'),
#  ('grant', 'concedere'),
#  ('grant', 'grant'),
#  ('minute', 'minuto'),
#  ('assets', 'beni'),
#  ('habitat', 'habitat'),
#  ('false', 'falsa'),
#  ('false', 'false'),
#  ('false', 'falsi'),
#  ('false', 'falso'),
#  ('privacy', 'privacy'),
#  ('their', 'loro'),
#  ('tom', 'tom'),
#  ('thanks', 'grazie'),
#  ('thanks', 'ringraziamenti'),
#  ('positive', 'positiva'),
#  ('positive', 'positivi'),
#  ('positive', 'positivo'),
#  ('storm', 'tempesta'),
#  ('essex', 'essex'),
#  ('sound', 'sound'),
#  ('imposed', 'imposte'),
#  ('imposed', 'imposti'),
#  ('imposed', 'imposto'),
#  ('fantastic', 'fantastico'),
#  ('shoes', 'calzature'),
#  ('shoes', 'scarpe'),
#  ('prince', 'prince'),
#  ('prince', 'principe'),
#  ('goods', 'beni'),
#  ('goods', 'merci'),
#  ('helps', 'aiuta'),
#  ('electronic', 'elettronica'),
#  ('electronic', 'elettroniche'),
#  ('electronic', 'elettronici'),
#  ('electronic', 'elettronico'),
#  ('specified', 'specificato'),
#  ('agents', 'agenti'),
#  ('improve', 'migliorare'),
#  ('recorded', 'registrati'),
#  ('recorded', 'registrato'),
#  ('assessment', 'valutazione'),
#  ('durham', 'durham'),
#  ('nothing', 'nulla'),
#  ('machines', 'macchine'),
#  ('convention', 'convenzione'),
#  ('forever', 'forever'),
#  ('wireless', 'wireless'),
#  ('crimes', 'crimini'),
#  ('crimes', 'reati'),
#  ('vietnam', 'vietnam'),
#  ('employee', 'dipendente'),
#  ('repeat', 'ripetere'),
#  ('transactions', 'operazioni'),
#  ('transactions', 'transazioni'),
#  ('air', 'aerei'),
#  ('air', 'aereo'),
#  ('air', 'air'),
#  ('air', 'aria'),
#  ('fleet', 'flotta'),
#  ('time', 'momento'),
#  ('time', 'tempo'),
#  ('time', 'volta'),
#  ('spring', 'primavera'),
#  ('ocean', 'oceano'),
#  ('decision', 'decisione'),
#  ('gifts', 'doni'),
#  ('gifts', 'regali'),
#  ('meaning', 'significato'),
#  ('conflict', 'conflitti'),
#  ('conflict', 'conflitto'),
#  ('offer', 'offerta'),
#  ('offer', 'offrire'),
#  ('ben', 'ben'),
#  ('consultant', 'consulente'),
#  ('concept', 'concetto'),
#  ('town', 'città'),
#  ('oak', 'quercia'),
#  ('oak', 'rovere'),
#  ('now', 'adesso'),
#  ('now', 'now'),
#  ('now', 'ora'),
#  ('alliance', 'alleanza'),
#  ('murray', 'murray'),
#  ('greater', 'greater'),
#  ('greater', 'maggiore'),
#  ('doors', 'porte'),
#  ('seminar', 'seminario'),
#  ('functional', 'funzionale'),
#  ('functional', 'funzionali'),
#  ('except', 'tranne'),
#  ('produced', 'prodotto'),
#  ('white', 'bianchi'),
#  ('white', 'bianco'),
#  ('hot', 'calda'),
#  ('hot', 'caldo'),
#  ('hot', 'fritta'),
#  ('bbc', 'bbc'),
#  ('that', 'che'),
#  ('brazil', 'brasile'),
#  ('excellence', 'eccellenza'),
#  ('rolling', 'rolling'),
#  ('patrick', 'patrick'),
#  ('action', 'azione'),
#  ('represents', 'rappresenta'),
#  ('graphics', 'grafica'),
#  ('graphics', 'grafico'),
#  ('borders', 'confini'),
#  ('borders', 'frontiere'),
#  ('note', 'nota'),
#  ('weak', 'debole'),
#  ('weak', 'deboli'),
#  ('lincoln', 'lincoln'),
#  ('awarded', 'assegnato'),
#  ('attract', 'attrarre'),
#  ('times', 'tempi'),
#  ('times', 'times'),
#  ('times', 'volte'),
#  ('restaurants', 'ristoranti'),
#  ('circle', 'cerchia'),
#  ('circle', 'cerchio'),
#  ('circle', 'circolo'),
#  ('circle', 'polare'),
#  ('coat', 'giacca'),
#  ('publisher', 'editore'),
#  ('tax', 'fiscale'),
#  ('tax', 'fiscali'),
#  ('tax', 'tassa'),
#  ('players', 'attori'),
#  ('players', 'giocatori'),
#  ('hamilton', 'hamilton'),
#  ('bath', 'bagno'),
#  ('bath', 'sporca'),
#  ('inclusion', 'inclusione'),
#  ('inclusion', 'inserimento'),
#  ('towards', 'verso'),
#  ('chair', 'presiedere'),
#  ('exercise', 'esercitare'),
#  ('exercise', 'esercizio'),
#  ('treated', 'trattati'),
#  ('india', 'india'),
#  ('assist', 'assistere'),
#  ('constant', 'costante'),
#  ('acquired', 'acquisita'),
#  ('acquired', 'acquisiti'),
#  ('acquired', 'acquisito'),
#  ('leaving', 'lasciando'),
#  ('desired', 'desiderato'),
#  ('poetry', 'poesia'),
#  ('engineer', 'ingegnere'),
#  ('main', 'meno'),
#  ('main', 'principale'),
#  ('main', 'principali'),
#  ('nuclear', 'nucleare'),
#  ('nuclear', 'nucleari'),
#  ('healthcare', 'sanitari'),
#  ('higher', 'superiore'),
#  ('organized', 'organizzata'),
#  ('mayor', 'mayor'),
#  ('mayor', 'sindaco'),
#  ('managed', 'riusciti'),
#  ('rooms', 'sale'),
#  ('rooms', 'stanze'),
#  ('holidays', 'vacanze'),
#  ('discuss', 'discutere'),
#  ('sheep', 'ovini'),
#  ('sheep', 'pecore'),
#  ('products', 'prodotti'),
#  ('seven', 'sette'),
#  ('for', 'per'),
#  ('protest', 'protesta'),
#  ('protest', 'protestare'),
#  ('laws', 'leggi'),
#  ('type', 'tipo'),
#  ('world', 'mondiale'),
#  ('world', 'mondo'),
#  ('destroy', 'distruggere'),
#  ('ball', 'palla'),
#  ('possibility', 'possibilità'),
#  ('capacity', 'capacità'),
#  ('marine', 'marine'),
#  ('marine', 'marini'),
#  ('marine', 'marino'),
#  ('will', 'intende'),
#  ('will', 'può'),
#  ('acquisition', 'acquisizione'),
#  ('integration', 'integrazione'),
#  ('blog', 'blog'),
#  ('personally', 'personalmente'),
#  ('ownership', 'proprietà'),
#  ('faith', 'fede'),
#  ('faith', 'feith'),
#  ('collection', 'raccolta'),
#  ('variety', 'varietà'),
#  ('leadership', 'guida'),
#  ('leadership', 'leadership'),
#  ('five', 'cinque'),
#  ('poker', 'poker'),
#  ('weather', 'meteorologiche'),
#  ('doubt', 'dubbio'),
#  ('directly', 'direttamente'),
#  ('widespread', 'diffusa'),
#  ('china', 'cina'),
#  ('china', 'cristalli'),
#  ('china', 'porcellane'),
#  ('exposure', 'esposizione'),
#  ('canada', 'canada'),
#  ('competition', 'concorrenza'),
#  ('alexander', 'alexander'),
#  ('ethics', 'etica'),
#  ('ethics', 'etico'),
#  ('beach', 'beach'),
#  ('beach', 'spiaggia'),
#  ('breast', 'materno'),
#  ('apple', 'apple'),
#  ('apple', 'mela'),
#  ('apple', 'mele'),
#  ('kennedy', 'kennedy'),
#  ('mission', 'missione'),
#  ('winter', 'invernali'),
#  ('winter', 'inverno'),
#  ('scientific', 'scientifica'),
#  ('scientific', 'scientifiche'),
#  ('scientific', 'scientifici'),
#  ('scientific', 'scientifico'),
#  ('administrative', 'amministrativa'),
#  ('administrative', 'amministrative'),
#  ('administrative', 'amministrativi'),
#  ('administrative', 'amministrativo'),
#  ('sussex', 'sussex'),
#  ('intermediate', 'intermedi'),
#  ('intermediate', 'intermedia'),
#  ('intermediate', 'intermedie'),
#  ('collections', 'collezioni'),
#  ('types', 'tipi'),
#  ('adam', 'adam'),
#  ('techniques', 'tecniche'),
#  ('guy', 'guy'),
#  ('compliance', 'conformità'),
#  ('christianity', 'cristianesimo'),
#  ('christianity', 'cristianità'),
#  ('competitive', 'competitiva'),
#  ('competitive', 'competitivi'),
#  ('competitive', 'competitivo'),
#  ('specifically', 'specificamente'),
#  ('cause', 'causa'),
#  ('perfectly', 'perfettamente'),
#  ('fed', 'alimentati'),
#  ('fed', 'fed'),
#  ('wish', 'desiderio'),
#  ('models', 'modelli'),
#  ('acres', 'acri'),
#  ('week', 'settimana'),
#  ('voted', 'votato'),
#  ('oral', 'orale'),
#  ('oral', 'orali'),
#  ('expand', 'espandere'),
#  ('stuart', 'stuart'),
#  ('rome', 'roma'),
#  ('presidential', 'presidenziale'),
#  ('presidential', 'presidenziali'),
#  ('recovered', 'recuperati'),
#  ('recovered', 'recuperato'),
#  ('front', 'front'),
#  ('front', 'fronte'),
#  ('began', 'iniziato'),
#  ('signs', 'segnali'),
#  ('signs', 'segni'),
#  ('bank', 'banca'),
#  ('bank', 'bancari'),
#  ('jews', 'ebrei'),
#  ('ensuring', 'garantire'),
#  ('cream', 'crema'),
#  ('cream', 'panna'),
#  ('growing', 'crescente'),
#  ('coaches', 'pullman'),
#  ('director', 'direttore'),
#  ('target', 'target'),
#  ('richard', 'richard'),
#  ('technical', 'tecnica'),
#  ('technical', 'tecniche'),
#  ('technical', 'tecnici'),
#  ('technical', 'tecnico'),
#  ('spectacular', 'spettacolare'),
#  ('spectacular', 'spettacolari'),
#  ('absolutely', 'assolutamente'),
#  ('reputation', 'reputazione'),
#  ('gap', 'divario'),
#  ('currently', 'attualmente'),
#  ('establishment', 'creazione'),
#  ('establishment', 'istituzione'),
#  ('berlin', 'berlino'),
#  ('level', 'livello'),
#  ('brighton', 'brighton'),
#  ('locally', 'localmente'),
#  ('according', 'secondo'),
#  ('met', 'incontrato'),
#  ('walk', 'camminare'),
#  ('opinion', 'opinione'),
#  ('opinion', 'parere'),
#  ('dimensions', 'dimensioni'),
#  ('atlantic', 'atlantica'),
#  ('atlantic', 'atlantico'),
#  ('security', 'sicurezza'),
#  ('agency', 'agenzia'),
#  ('pressure', 'pressione'),
#  ('pressure', 'pressioni'),
#  ('von', 'von'),
#  ('scholars', 'studiosi'),
#  ('opposite', 'opposto'),
#  ('quickly', 'rapidamente'),
#  ('revolutionary', 'rivoluzionari'),
#  ('revolutionary', 'rivoluzionaria'),
#  ('revolutionary', 'rivoluzionarie'),
#  ('revolutionary', 'rivoluzionario'),
#  ('assume', 'assumersi'),
#  ('office', 'carica'),
#  ('office', 'ufficio'),
#  ('actions', 'azioni'),
#  ('membership', 'adesione'),
#  ('big', 'big'),
#  ('big', 'grande'),
#  ('big', 'grandi'),
#  ('trophy', 'trofei'),
#  ('phone', 'telefonia'),
#  ('phone', 'telefono'),
#  ('meals', 'pasti'),
#  ('session', 'sessione'),
#  ('peter', 'peter'),
#  ('manufacture', 'fabbricazione'),
#  ('commissioner', 'commissario'),
#  ('sir', 'sir'),
#  ('certainly', 'certamente'),
#  ('certainly', 'sicuramente'),
#  ('aims', 'mira'),
#  ('sleep', 'dormire'),
#  ('sleep', 'sonno'),
#  ('control', 'controllo'),
#  ('flag', 'bandiera'),
#  ('pension', 'pensione'),
#  ('pension', 'pensionistici'),
#  ('temperature', 'temperatura'),
#  ('common', 'comune'),
#  ('common', 'comuni'),
#  ('two', 'due'),
#  ('commonwealth', 'commonwealth'),
#  ('save', 'risparmiare'),
#  ('save', 'salvare'),
#  ('save', 'save'),
#  ('lost', 'perso'),
#  ('egypt', 'egitto'),
#  ('qualification', 'qualifica'),
#  ('qualification', 'qualificazione'),
#  ('rent', 'affitto'),
#  ('considerable', 'notevole'),
#  ('considerable', 'notevoli'),
#  ('thursday', 'giovedì'),
#  ('interviews', 'interviste'),
#  ('formula', 'formula'),
#  ('biography', 'biografia'),
#  ('similarly', 'analogamente'),
#  ('illness', 'malattia'),
#  ('rights', 'diritti'),
#  ('cameras', 'telecamere'),
#  ('operation', 'funzionamento'),
#  ('operation', 'operazione'),
#  ('swedish', 'svedese'),
#  ('swedish', 'svedesi'),
#  ('dual', 'doppia'),
#  ('dual', 'duplice'),
#  ('taxes', 'imposte'),
#  ('taxes', 'tasse'),
#  ('periods', 'periodi'),
#  ('project', 'progetto'),
#  ('strong', 'forte'),
#  ('strong', 'forti'),
#  ('replaced', 'sostituita'),
#  ('replaced', 'sostituiti'),
#  ('replaced', 'sostituito'),
#  ('defeated', 'sconfitto'),
#  ('theatre', 'teatro'),
#  ('tracks', 'binari'),
#  ('category', 'categoria'),
#  ('category', 'rubrica'),
#  ('aircraft', 'aerei'),
#  ('aircraft', 'aeromobili'),
#  ('aircraft', 'aircraft'),
#  ('william', 'william'),
#  ('devon', 'devon'),
#  ('georgia', 'georgia'),
#  ('fantasy', 'fantasia'),
#  ('plastic', 'plastica'),
#  ('heart', 'centro'),
#  ('heart', 'cuore'),
#  ('especially', 'particolare'),
#  ('especially', 'soprattutto'),
#  ('shipping', 'navigazione'),
#  ('lower', 'bassa'),
#  ('lower', 'inferiori'),
#  ('allied', 'alleate'),
#  ('jason', 'jason'),
#  ('tried', 'cercato'),
#  ('tried', 'tentato'),
#  ('sand', 'sabbia'),
#  ('corresponding', 'corrispondente'),
#  ('corresponding', 'corrispondenti'),
#  ('walked', 'camminato'),
#  ('graphic', 'grafici'),
#  ('indicated', 'indicato'),
#  ('refugees', 'profughi'),
#  ('refugees', 'rifugiati'),
#  ('ordered', 'ordinato'),
#  ('spaces', 'spazi'),
#  ('information', 'informazione'),
#  ('information', 'informazioni'),
#  ('winning', 'vincere'),
#  ('seek', 'cercare'),
#  ('regeneration', 'rigenerazione'),
#  ('memorial', 'memorial'),
#  ('brilliant', 'brillante'),
#  ('river', 'fiume'),
#  ('river', 'fluviale'),
#  ('river', 'fluviali'),
#  ('distance', 'distanza'),
#  ('rob', 'rob'),
#  ('effort', 'sforzo'),
#  ('owners', 'proprietari'),
#  ('forward', 'avanti'),
#  ('storage', 'stoccaggio'),
#  ('negative', 'negativa'),
#  ('negative', 'negative'),
#  ('negative', 'negativi'),
#  ('negative', 'negativo'),
#  ('developments', 'sviluppi'),
#  ('apply', 'applicare'),
#  ('export', 'esportare'),
#  ('export', 'esportazione'),
#  ('detail', 'dettagli'),
#  ('detail', 'dettaglio'),
#  ('known', 'nota'),
#  ('known', 'noto'),
#  ('executed', 'giustiziati'),
#  ('executed', 'giustiziato'),
#  ('forum', 'forum'),
#  ('seconds', 'secondi'),
#  ('steps', 'passi'),
#  ('enjoy', 'godere'),
#  ('cases', 'casi'),
#  ('education', 'istruzione'),
#  ('focus', 'concentrarsi'),
#  ('focus', 'focus'),
#  ('asylum', 'asilo'),
#  ('wilson', 'wilson'),
#  ('tony', 'tony'),
#  ('yet', 'ancora'),
#  ('iran', 'iran'),
#  ('sign', 'firmare'),
#  ('sign', 'segnale'),
#  ('sign', 'segno'),
#  ('islamic', 'islamica'),
#  ('islamic', 'islamici'),
#  ('islamic', 'islamico'),
#  ('public', 'pubblica'),
#  ('public', 'pubblici'),
#  ('public', 'pubblico'),
#  ('neighbourhood', 'vicinato'),
#  ('servers', 'server'),
#  ('between', 'fra'),
#  ('between', 'tra'),
#  ('edward', 'edward'),
#  ('urban', 'urban'),
#  ('urban', 'urbana'),
#  ('urban', 'urbane'),
#  ('urban', 'urbani'),
#  ('urban', 'urbano'),
#  ('weapons', 'armi'),
#  ('positions', 'posizioni'),
#  ('investigations', 'indagini'),
#  ('suggestions', 'suggerimenti'),
#  ('weeks', 'settimane'),
#  ('way', 'modo'),
#  ('rules', 'norme'),
#  ('rules', 'regolamento'),
#  ('rules', 'regole'),
#  ('attempting', 'tentando'),
#  ('wing', 'ala'),
#  ('opposition', 'opposizione'),
#  ('reverse', 'invertire'),
#  ('classic', 'classica'),
#  ('classic', 'classico'),
#  ('geography', 'geografia'),
#  ('matter', 'questione'),
#  ('pilot', 'pilota'),
#  ('hampshire', 'hampshire'),
#  ('solid', 'solida'),
#  ('solid', 'solide'),
#  ('solid', 'solido'),
#  ('challenges', 'sfide'),
#  ('wisdom', 'saggezza'),
#  ('six', 'sei'),
#  ('breaking', 'breaking'),
#  ('contemporary', 'contemporanea'),
#  ('contemporary', 'contemporaneo'),
#  ('publicly', 'pubblicamente'),
#  ('term', 'semestre'),
#  ('term', 'termine'),
#  ('map', 'map'),
#  ('map', 'marcia'),
#  ('jesus', 'gesù'),
#  ('reflects', 'riflette'),
#  ('reflects', 'rispecchia'),
#  ('blood', 'sangue'),
#  ('marketing', 'commercializzazione'),
#  ('ask', 'chiedere'),
#  ('reaction', 'reazione'),
#  ('loan', 'prestito'),
#  ('collaboration', 'collaboration'),
#  ('collaboration', 'collaborazione'),
#  ('spending', 'spesa'),
#  ('legend', 'leggenda'),
#  ('these', 'queste'),
#  ('these', 'questi'),
#  ('these', 'tali'),
#  ('wales', 'galles'),
#  ('enter', 'entrare'),
#  ('dvd', 'dvd'),
#  ('jean', 'jean'),
#  ('say', 'dire'),
#  ('pleasant', 'piacevole'),
#  ('fair', 'equa'),
#  ('fair', 'equo'),
#  ('fair', 'fair'),
#  ('walker', 'walker'),
#  ('postgraduate', 'postlaurea'),
#  ('necessary', 'necessari'),
#  ('necessary', 'necessaria'),
#  ('necessary', 'necessarie'),
#  ('necessary', 'necessario'),
#  ('plants', 'impianti'),
#  ('plants', 'piante'),
#  ('sunday', 'domenica'),
#  ('lake', 'lago'),
#  ('page', 'pagina'),
#  ('unions', 'sindacati'),
#  ('character', 'carattere'),
#  ('center', 'center'),
#  ('ict', 'tic'),
#  ('feed', 'mangimi'),
#  ('limited', 'limitata'),
#  ('limited', 'limitate'),
#  ('limited', 'limitato'),
#  ('limited', 'limited'),
#  ('slowly', 'lentamente'),
#  ('cope', 'cope'),
#  ('medical', 'medica'),
#  ('medical', 'medical'),
#  ('medical', 'mediche'),
#  ('medical', 'medici'),
#  ('medical', 'medico'),
#  ('williams', 'williams'),
#  ('belfast', 'belfast'),
#  ('buried', 'sepolta'),
#  ('buried', 'sepolto'),
#  ('brings', 'porta'),
#  ('cricket', 'cricket'),
#  ('literally', 'letteralmente'),
#  ('melbourne', 'melbourne'),
#  ('shares', 'condivide'),
#  ('desk', 'scrivania'),
#  ('logic', 'logica'),
#  ('force', 'force'),
#  ('force', 'forza'),
#  ('force', 'vigore'),
#  ('thomas', 'thomas'),
#  ('underground', 'sotterranee'),
#  ('monday', 'lunedì'),
#  ('christian', 'cristiana'),
#  ('christian', 'cristiane'),
#  ('christian', 'cristiani'),
#  ('christian', 'cristiano'),
#  ('cuts', 'tagli'),
#  ('path', 'cammino'),
#  ('path', 'percorso'),
#  ('path', 'strada'),
#  ('circumstances', 'circostanze'),
#  ('nature', 'carattere'),
#  ('nature', 'natura'),
#  ('nature', 'nature'),
#  ('structure', 'struttura'),
#  ('works', 'funziona'),
#  ('works', 'opere'),
#  ('courses', 'corsi'),
#  ('continental', 'continentale'),
#  ('continental', 'continentali'),
#  ('kinds', 'tipi'),
#  ('wave', 'ondata'),
#  ('seeds', 'sementi'),
#  ('seeds', 'semi'),
#  ('include', 'includere'),
#  ('eight', 'otto'),
#  ('scenes', 'quinte'),
#  ('scenes', 'scene'),
#  ('society', 'società'),
#  ('normally', 'normalmente'),
#  ('button', 'bottone'),
#  ('button', 'pulsante'),
#  ('button', 'tasto'),
#  ('mainly', 'principalmente'),
#  ('interest', 'interesse'),
#  ('been', 'stata'),
#  ('been', 'stati'),
#  ('been', 'stato'),
#  ('body', 'corpo'),
#  ('body', 'organismo'),
#  ('body', 'organo'),
#  ('actor', 'attore'),
#  ('channels', 'canali'),
#  ('wars', 'guerre'),
#  ('feature', 'caratteristica'),
#  ('clubs', 'club'),
#  ('achievement', 'raggiungimento'),
#  ('howard', 'howard'),
#  ('mrs', 'onorevole'),
#  ('tourist', 'turistica'),
#  ('tourist', 'turistiche'),
#  ('tourist', 'turistici'),
#  ('tourist', 'turistico'),
#  ('twenty', 'venti'),
#  ('properly', 'adeguatamente'),
#  ('properly', 'correttamente'),
#  ('shower', 'doccia'),
#  ('liverpool', 'liverpool'),
#  ('film', 'cinematografica'),
#  ('film', 'cinematografico'),
#  ('film', 'film'),
#  ('illinois', 'illinois'),
#  ('van', 'van'),
#  ('plan', 'piano'),
#  ('daughter', 'figlia'),
#  ('characteristics', 'caratteristiche'),
#  ('prisoners', 'detenuti'),
#  ('prisoners', 'prigionieri'),
#  ('hopes', 'speranze'),
#  ('paul', 'paolo'),
#  ('paul', 'paul'),
#  ('here', 'qui'),
#  ('interactive', 'interattiva'),
#  ('interactive', 'interattivi'),
#  ('interactive', 'interattivo'),
#  ...]

# %%
def get_wlists(wps):
    wl1 = set()
    wl2 = set()
    for (w1, w2) in wps:
        wl1.add(w1)
        wl2.add(w2)
    return wl1, wl2

# %%
tr_en, tr_it = get_wlists(train_wps)
va_en, va_it = get_wlists(valid_wps)

len(tr_en)
len(tr_it)
len(va_en)
len(va_it)
# Out:
# 3098
# 4129
# 344
# 499

# %%
overlap_en = set(tr_en) & set(va_en)
overlap_it = set(tr_it) & set(va_it)
len(overlap_en)
len(overlap_it)
# Out:
# 0
# 80

# %%
def wp_list_2_dict(wp_l):
    l12 = dict()
    l21 = dict()
    for (w1, w2) in wp_l:
        if w1 not in l12:
            l12[w1] = [w2]
        else:
            l12[w1].append(w2)
        if w2 not in l21:
            l21[w2] = [w1]
        else:
            l21[w2].append(w1)
    return l12, l21

# %%
tr_en_it, tr_it_en = wp_list_2_dict(train_wps)
va_en_it, va_it_en = wp_list_2_dict(valid_wps)

# %%
fatal = 0
for w in overlap_it:
    print(w)
    w_tr = tr_it_en[w]
    w_va = va_it_en[w]
    if w_tr == w_va:
        fatal += 1
    print('train: {}'.format(w_tr))
    print('test: {}'.format(w_va))
    
print('fatal: {}'.format(fatal))
# Out:
# vendita
# train: ['sale', 'sales']
# test: ['selling']
# ogni
# train: ['every', 'any']
# test: ['each']
# voto
# train: ['voting']
# test: ['vote']
# contatti
# train: ['contacts']
# test: ['contact']
# quota
# train: ['proportion']
# test: ['share']
# vendere
# train: ['sell']
# test: ['selling']
# porta
# train: ['brings', 'door']
# test: ['leads']
# migliore
# train: ['better']
# test: ['best']
# morte
# train: ['kill']
# test: ['death']
# membri
# train: ['members']
# test: ['member']
# animali
# train: ['animals']
# test: ['animal']
# ferroviario
# train: ['railway']
# test: ['rail']
# dettagli
# train: ['detail']
# test: ['details']
# ramo
# train: ['arm']
# test: ['branch']
# maggiore
# train: ['greater']
# test: ['increased']
# aula
# train: ['chamber']
# test: ['house']
# ascolto
# train: ['listen']
# test: ['listening']
# importo
# train: ['amount']
# test: ['sum']
# assemblea
# train: ['assembly']
# test: ['house']
# carriera
# train: ['career']
# test: ['careers']
# ultimi
# train: ['recent']
# test: ['last']
# discussione
# train: ['discussion']
# test: ['debate']
# promozione
# train: ['promotion']
# test: ['promoting']
# comuni
# train: ['common']
# test: ['commons']
# istituzione
# train: ['establishment']
# test: ['institution']
# applicazione
# train: ['application']
# test: ['implementation']
# rapporti
# train: ['relationship']
# test: ['relations']
# meglio
# train: ['better']
# test: ['best']
# sacre
# train: ['holy']
# test: ['sacred']
# vincere
# train: ['winning']
# test: ['win']
# osservazioni
# train: ['comments']
# test: ['observations']
# segnale
# train: ['sign']
# test: ['signal']
# quantità
# train: ['amount']
# test: ['quantity']
# impresa
# train: ['company', 'enterprise']
# test: ['undertaking']
# perdere
# train: ['losing']
# test: ['lose']
# unità
# train: ['unity', 'units']
# test: ['unit']
# soldato
# train: ['soldier']
# test: ['bronze']
# marchio
# train: ['label']
# test: ['mark']
# droga
# train: ['drug']
# test: ['drugs']
# ultima
# train: ['final']
# test: ['last']
# appello
# train: ['call']
# test: ['appeal']
# contribuire
# train: ['help']
# test: ['contribute']
# rispondere
# train: ['answer']
# test: ['respond']
# questione
# train: ['matter', 'question']
# test: ['issue']
# professionali
# train: ['professional']
# test: ['occupational']
# bar
# train: ['bars']
# test: ['bar']
# tenendo
# train: ['bearing']
# test: ['taking']
# cristiani
# train: ['christian']
# test: ['christians']
# editori
# train: ['editors']
# test: ['publishers']
# controllato
# train: ['controlled']
# test: ['checked']
# regolamentazione
# train: ['regulatory']
# test: ['regulation']
# sale
# train: ['rooms']
# test: ['salt']
# regolamento
# train: ['rules', 'procedure']
# test: ['regulation']
# circa
# train: ['approximately']
# test: ['around']
# relazioni
# train: ['reports']
# test: ['relations']
# responsabilità
# train: ['responsibility']
# test: ['producer']
# meno
# train: ['main']
# test: ['less']
# parità
# train: ['equal']
# test: ['equality']
# accessibili
# train: ['accessible']
# test: ['affordable']
# migliori
# train: ['better']
# test: ['best']
# iniziato
# train: ['began', 'begun']
# test: ['started']
# fondamentali
# train: ['basic']
# test: ['fundamental']
# evitare
# train: ['prevent']
# test: ['avoid']
# vita
# train: ['lives', 'life']
# test: ['living']
# promuovere
# train: ['promote']
# test: ['promoting']
# primo
# train: ['first']
# test: ['prime']
# questioni
# train: ['questions', 'issues']
# test: ['matters']
# foto
# train: ['photographs', 'photo']
# test: ['photos']
# acquistare
# train: ['purchase']
# test: ['buy']
# costi
# train: ['cost']
# test: ['costs']
# fondamentale
# train: ['essential']
# test: ['fundamental']
# filo
# train: ['thread']
# test: ['wire']
# fotografie
# train: ['photographs']
# test: ['photos']
# organizzazione
# train: ['organization']
# test: ['organisation']
# casa
# train: ['home']
# test: ['house']
# contenuti
# train: ['content']
# test: ['contained']
# identificare
# train: ['identifying']
# test: ['identify']
# cattura
# train: ['capture']
# test: ['catch']
# produttore
# train: ['manufacturer']
# test: ['producer']
# ali
# train: ['wings']
# test: ['ali']
# fatal: 0
